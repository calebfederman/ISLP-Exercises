# %% [markdown]
# ## Chapter 2 (Statistical Learning) Applied Exercises

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### Exercise 8

# %%
# 8.a

college = pd.read_csv('./data/College.csv')
college
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %%
# 8.b

college2 = pd.read_csv('./data/College.csv', index_col=0)
college3 = college.rename({'Unnamed: 0' : 'College'},
                         axis=1)
college3 = college3.set_index('College')
college = college3
college
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %%
# 8.c

college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
# 8.d

filter_columns = ['Top10perc','Apps','Enroll']

pd.plotting.scatter_matrix(college[filter_columns]);

# %%
# 8.e

college.boxplot('Outstate', by='Private');

# %%
# 8.f

college['Elite'] = pd.cut(college['Top10perc']/college['Enroll'],
                          [0,0.5,1],
                          labels=['No','Yes'])

college['Elite'].value_counts()
# Out:
# Elite
# No     775
# Yes      2
# Name: count, dtype: int64

# %%
college.boxplot('Outstate', by='Elite');

# %%
# 8.g

fig, ax = plt.subplots(2, 2)
college.hist('PhD',bins=20,ax=ax[0][0],grid=False)
college.hist('Grad.Rate',bins=20,ax=ax[0][1],grid=False)
college.hist('Outstate',bins=5,ax=ax[1][0],grid=False)
college.hist('Room.Board',bins=5,ax=ax[1][1],grid=False);

# %%
# 8.h

college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
fig, ax = plt.subplots(1,3, figsize=(9,3))
ax[0].set_xlabel('% of Faculty with PhD')
ax[0].set_ylabel('Graduation Rate')
ax[0].scatter(college['PhD'],college['Grad.Rate'], marker='.')
ax[1].set_xlabel('Student Faculty Ratio')
ax[1].set_ylabel('Graduation Rate')
ax[1].scatter(college['S.F.Ratio'],college['Grad.Rate'], marker='.')
ax[2].set_xlabel('Expenditure per Student')
ax[2].set_ylabel('Graduation Rate')
ax[2].scatter(college['Expend'],college['Grad.Rate'], marker='.');

# %%
pd.plotting.scatter_matrix(college[['Expend',
                                    'Enroll',
                                    'S.F.Ratio']], figsize=(10,10));

# %% [markdown]
# 8.h
#
# One interesting thing I noticed is that the max graduation rate is 118% and the max percent of faculty with PhDs is 103%. This indicates some sort of error in data collection or calculation.
#
# Also, as Student-Faculty Ratio increases, Instructional Expenditure per Student tends to decrease. This makes sense intuitively since there are fewer faculty being paid to support each student. Similarly, schools with very high enrollment seem to be limited in the area of instructional expenditure per student. These observations are likely related.

# %% [markdown]
# ### Exercise 9
